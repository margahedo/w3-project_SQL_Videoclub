# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_columns', None)  # display all columns
pd.set_option('display.max_rows', None)  # display all rows

# %%
actor_ori = pd.read_csv("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/actor.csv")
category_ori = pd.read_csv("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/category.csv")
film_ori = pd.read_csv("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/film.csv")
inventory_ori = pd.read_csv("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/inventory.csv")
language_ori = pd.read_csv ("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/language.csv")
old_HDD_ori = pd.read_csv ("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/old_HDD.csv")
rental_ori = pd.read_csv ("/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/data/rental.csv")

# %%
print('Actores: ', actor_ori.shape)
print('Categorias: ', category_ori.shape)
print('Películas: ', film_ori.shape)
print('Inventario: ', inventory_ori.shape)
print('Idioma: ', language_ori.shape)
print('Columna: ', old_HDD_ori.shape)
print('Alquiler: ', rental_ori.shape)
# Out:
# Actores:  (200, 4)
# Categorias:  (16, 3)
# Películas:  (1000, 13)
# Inventario:  (1000, 4)
# Idioma:  (6, 3)
# Columna:  (1000, 5)
# Alquiler:  (1000, 7)

# %%
actor_ori.head()
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2         3         ED         CHASE  2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33

# %%
actor = actor_ori.assign(actor_actress_name = (actor_ori['first_name'] + ' ' + actor_ori['last_name']).str.lower())
actor.head()
# Out:
#    actor_id first_name     last_name          last_update   actor_actress_name
# 0         1   PENELOPE       GUINESS  2006-02-15 04:34:33     penelope guiness
# 1         2       NICK      WAHLBERG  2006-02-15 04:34:33        nick wahlberg
# 2         3         ED         CHASE  2006-02-15 04:34:33             ed chase
# 3         4   JENNIFER         DAVIS  2006-02-15 04:34:33       jennifer davis
# 4         5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33  johnny lollobrigida

# %%
actor.duplicated(subset=['actor_actress_name']).value_counts()
# Out:
# False    199
# True       1
# dtype: int64

# %%
duplicates = actor.duplicated(subset=['actor_actress_name'], keep=False)
duplicated_rows = actor[duplicates]
duplicated_rows
# Out:
#      actor_id first_name last_name          last_update actor_actress_name
# 100       101      SUSAN     DAVIS  2006-02-15 04:34:33        susan davis
# 109       110      SUSAN     DAVIS  2006-02-15 04:34:33        susan davis

# %%
actor = actor.drop(index=[109])

# %%
actor = actor.drop(columns=['first_name', 'last_name', 'last_update'])
actor.head()
# Out:
#    actor_id   actor_actress_name
# 0         1     penelope guiness
# 1         2        nick wahlberg
# 2         3             ed chase
# 3         4       jennifer davis
# 4         5  johnny lollobrigida

# %%
category_ori.head()
# Out:
#    category_id       name          last_update
# 0            1     Action  2006-02-15 04:46:27
# 1            2  Animation  2006-02-15 04:46:27
# 2            3   Children  2006-02-15 04:46:27
# 3            4   Classics  2006-02-15 04:46:27
# 4            5     Comedy  2006-02-15 04:46:27

# %%
category = category_ori.drop(columns=['last_update'])
category.head()
# Out:
#    category_id       name
# 0            1     Action
# 1            2  Animation
# 2            3   Children
# 3            4   Classics
# 4            5     Comedy

# %%
film_ori.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                   NaN                6         0.99      86
# 1            1                   NaN                3         4.99      48
# 2            1                   NaN                7         2.99      50
# 3            1                   NaN                5         2.99     117
# ...

# %%
film_ori["title"].value_counts().sum()
# Out:
# 1000

# %%
film_ori['subtitles_id'] = 0
film_ori["original_language_id"] = 0
film_ori.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                     0                6         0.99      86
# 1            1                     0                3         4.99      48
# 2            1                     0                7         2.99      50
# 3            1                     0                5         2.99     117
# ...

# %%
film = film_ori.drop(columns = "last_update")
film = film_ori.drop(columns = "rental_duration")

film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_rate  length  replacement_cost  \
# 0            1                     0         0.99      86             20.99
# 1            1                     0         4.99      48             12.99
# 2            1                     0         2.99      50             18.99
# ...

# %%
film.rename(columns={"rental_rate": "rental_price"}, inplace=True)

# %%
film["rental_price"] = 0
film["replacement_cost"] = 0

# %%
film.tail()
# Out:
#      film_id              title  \
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# 996  A Touching Drama of a Teacher And a Cat who mu...          2006
# 997  A Fateful Yarn of a Composer And a Man who mus...          2006
# 998  A Fateful Reflection of a Waitress And a Boat ...          2006
# 999  A Intrepid Panorama of a Mad Scientist And a B...          2006
#
#      language_id  original_language_id  rental_price  length  \
# 995            1                     0             0     183
# 996            1                     0             0     179
# 997            1                     0             0     105
# 998            1                     0             0     101
# ...

# %%
inventory_ori.head()
# Out:
#    inventory_id  film_id  store_id          last_update
# 0             1        1         1  2006-02-15 05:09:17
# 1             2        1         1  2006-02-15 05:09:17
# 2             3        1         1  2006-02-15 05:09:17
# 3             4        1         1  2006-02-15 05:09:17
# 4             5        1         2  2006-02-15 05:09:17

# %%
x = len(rental_ori['inventory_id'].unique())
y = inventory_ori["film_id"].max()
z = rental_ori["inventory_id"].max()
aproximate_number_of_total_films = (y*z)/x

aproximate_number_of_total_films
# Out:
# 1021.563

# %%
inventory = inventory_ori.drop("store_id", axis=1)

# %%
inventory.rename(columns={"last_update": "last_inventory_date"}, inplace=True)

# %%
inventory["last_inventory_date"] = "2001-01-01 00:00:00"

inventory.head()
# Out:
#    inventory_id  film_id  last_inventory_date
# 0             1        1  2001-01-01 00:00:00
# 1             2        1  2001-01-01 00:00:00
# 2             3        1  2001-01-01 00:00:00
# 3             4        1  2001-01-01 00:00:00
# 4             5        1  2001-01-01 00:00:00

# %%
language_ori.head()
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19

# %%
language = language_ori.drop(columns=['last_update'])

language = language_ori.rename(columns={'name': 'language_audio'})

language.head()
# Out:
#    language_id language_audio          last_update
# 0            1        English  2006-02-15 05:02:19
# 1            2        Italian  2006-02-15 05:02:19
# 2            3       Japanese  2006-02-15 05:02:19
# 3            4       Mandarin  2006-02-15 05:02:19
# 4            5         French  2006-02-15 05:02:19

# %%
data = {
    'original_language_id': [1, 2, 3, 4, 5, 6, 7],
    'original_language_audio': ['English', 'Italian', 'Japanese', "Mandarin", "French", "German", " Spanish"]
}

original_language = pd.DataFrame(data)

# %%
original_language
# Out:
#    original_language_id original_language_audio
# 0                     1                 English
# 1                     2                 Italian
# 2                     3                Japanese
# 3                     4                Mandarin
# 4                     5                  French
# 5                     6                  German
# 6                     7                 Spanish

# %%
data = {
    'subtitles_id': [1, 2, 3, 4, 5, 6, 7],
    'subtitles_language': ['English', 'Italian', 'Japanese', "Mandarin", "French", "German", " Spanish"]
}

subtitles = pd.DataFrame(data)

subtitles
# Out:
#    subtitles_id subtitles_language
# 0             1            English
# 1             2            Italian
# 2             3           Japanese
# 3             4           Mandarin
# 4             5             French
# 5             6             German
# 6             7            Spanish

# %%
rental_ori.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date  staff_id          last_update
# 0  2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33         1  2006-02-15 21:30:53
# 2  2005-06-01 22:12:39         1  2006-02-15 21:30:53
# 3  2005-06-03 01:43:41         2  2006-02-15 21:30:53
# 4  2005-06-02 04:33:21         1  2006-02-15 21:30:53

# %%
len(rental_ori['inventory_id'].unique())
# Out:
# 1000

# %%
rental_ori["inventory_id"].max()
# Out:
# 4581

# %%
rental = rental_ori.drop(columns = ["last_update"])

rental = rental_ori.drop (columns = ["staff_id"])

rental.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date          last_update
# 0  2005-05-26 22:04:30  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33  2006-02-15 21:30:53
# 2  2005-06-01 22:12:39  2006-02-15 21:30:53
# 3  2005-06-03 01:43:41  2006-02-15 21:30:53
# 4  2005-06-02 04:33:21  2006-02-15 21:30:53

# %%
rental["inventory_id"] = 0

rental["customer_id"] = 0
rental.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30             0            0
# 1          2  2005-05-24 22:54:33             0            0
# 2          3  2005-05-24 23:03:39             0            0
# 3          4  2005-05-24 23:04:41             0            0
# 4          5  2005-05-24 23:05:21             0            0
#
#            return_date          last_update
# 0  2005-05-26 22:04:30  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33  2006-02-15 21:30:53
# 2  2005-06-01 22:12:39  2006-02-15 21:30:53
# 3  2005-06-03 01:43:41  2006-02-15 21:30:53
# 4  2005-06-02 04:33:21  2006-02-15 21:30:53

# %%
rental["return_date"] = "2001-01-01 00:00:00"

rental["rental_date"] = "2001-01-01 00:00:00"

rental.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2001-01-01 00:00:00             0            0
# 1          2  2001-01-01 00:00:00             0            0
# 2          3  2001-01-01 00:00:00             0            0
# 3          4  2001-01-01 00:00:00             0            0
# 4          5  2001-01-01 00:00:00             0            0
#
#            return_date          last_update
# 0  2001-01-01 00:00:00  2006-02-15 21:30:53
# 1  2001-01-01 00:00:00  2006-02-15 21:30:53
# 2  2001-01-01 00:00:00  2006-02-15 21:30:53
# 3  2001-01-01 00:00:00  2006-02-15 21:30:53
# 4  2001-01-01 00:00:00  2006-02-15 21:30:53

# %%
rental["customer_name"] = "Unknown"
rental["telephone"] = "+34000000000"
rental["email"] = "unknown@unknown.com"

rental.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2001-01-01 00:00:00             0            0
# 1          2  2001-01-01 00:00:00             0            0
# 2          3  2001-01-01 00:00:00             0            0
# 3          4  2001-01-01 00:00:00             0            0
# 4          5  2001-01-01 00:00:00             0            0
#
#            return_date          last_update customer_name     telephone  \
# 0  2001-01-01 00:00:00  2006-02-15 21:30:53       Unknown  +34000000000
# 1  2001-01-01 00:00:00  2006-02-15 21:30:53       Unknown  +34000000000
# 2  2001-01-01 00:00:00  2006-02-15 21:30:53       Unknown  +34000000000
# 3  2001-01-01 00:00:00  2006-02-15 21:30:53       Unknown  +34000000000
# 4  2001-01-01 00:00:00  2006-02-15 21:30:53       Unknown  +34000000000
#
#                  email
# 0  unknown@unknown.com
# 1  unknown@unknown.com
# 2  unknown@unknown.com
# 3  unknown@unknown.com
# 4  unknown@unknown.com

# %%
old_HDD_ori.head()
# Out:
#   first_name last_name                  title  release_year  category_id
# 0   PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1   PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2   PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3   PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4   PENELOPE   GUINESS          CHEAPER CLYDE          2006           14

# %%
old_HDD = old_HDD_ori.drop(columns=['first_name', 'last_name'])
old_HDD.head()
# Out:
#                    title  release_year  category_id
# 0       ACADEMY DINOSAUR          2006            6
# 1   ANACONDA CONFESSIONS          2006            2
# 2            ANGELS LIFE          2006           13
# 3  BULWORTH COMMANDMENTS          2006           10
# 4          CHEAPER CLYDE          2006           14

# %%
duplicates = old_HDD.duplicated()
duplicates.value_counts()
# Out:
# False    614
# True     386
# dtype: int64

# %%
actor_per_film = old_HDD.copy()

actor_per_film["actor_per_film_id"] = range(len(actor_per_film))

actor_per_film.head()
# Out:
#                    title  release_year  category_id  actor_per_film_id
# 0       ACADEMY DINOSAUR          2006            6                  0
# 1   ANACONDA CONFESSIONS          2006            2                  1
# 2            ANGELS LIFE          2006           13                  2
# 3  BULWORTH COMMANDMENTS          2006           10                  3
# 4          CHEAPER CLYDE          2006           14                  4

# %%
#inventory.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/inventory.csv', index=False)
#film.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/film.csv',index=False)
#language.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/language.csv',index=False)
#original_language.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/original_language.csv',index=False)
#subtitles.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/subtitles.csv',index=False)
#actor.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/actor.csv',index=False)
#category.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/category.csv',index=False)
#actor_per_film.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/actor_per_film.csv',index=False)
#rental.to_csv('/Users/margahedo/Desktop/Ironhack/w3-project_SQL_Videoclub/Data_Clean/rental.csv',index=False)
